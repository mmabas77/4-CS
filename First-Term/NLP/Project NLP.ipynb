# %%
# ----- ----- Importing Section ----- ----- 
# Data libraries
import pandas as pd
import numpy as np

# ML Libraries
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import pickle
from sklearn import metrics
# My utils
from sklearn.feature_extraction.text import CountVectorizer
from utils import df_utils
from sklearn.feature_extraction.text import TfidfVectorizer
from utils import nlp_utils


# ----- ----- ----- END ----- ----- -----

# %%
def read_data():
    true_df = df_utils.csv_to_dataframe(pd, './dataset/True.csv')
    true_df["c"] = 1
    false_df = df_utils.csv_to_dataframe(pd, './dataset/Fake.csv')
    false_df["c"] = 0
    df = pd.concat([true_df, false_df])
    df = df.sample(frac=1)
    df.reset_index(inplace=True)
    df.drop(["index"], axis=1, inplace=True)

    # Todo : Remove this in production code
    df = df[:3]

    return df

# %%
def prepare_data_frame():
    # Read data
    df = read_data()
    # Explore & Plot - 1
    explore_and_plot_df(df)
    # Enhance
    df = enhance(df)
    # Explore & Plot - 2
    explore_and_plot_df(df)
    # Return
    return df

# %%
def enhance(df):
    df = df_utils.drop_cols_with_names(df, 'title', 'subject', 'date')
    df = df_utils.drop_rows_with_null(df)
    # Corpus calculations as text
    df = process_df_text(df)

    return df

# %%
def process_df_text(df):
    # Lowercase
    df['text'] = df['text'].str.lower()

    # Stopwords
    # df['stopwords'] = df.apply(
    #     lambda row: nlp_utils.count_stopwords(row['text']),
    #     axis=1
    # )
    df['text'] = df.apply(
        lambda row: nlp_utils.remove_stopwords(row['text']),
        axis=1
    )

    # Punctuations
    # df['punctuations'] = df.apply(
    #     lambda row: nlp_utils.count_punctuation(row['text']),
    #     axis=1
    # )
    df['text'] = df.apply(
        lambda row: nlp_utils.remove_punctuation(row['text']),
        axis=1
    )

    # Stem
    df['text_stem'] = df.apply(
        lambda row: nlp_utils.porter_stemmer(row['text']),
        axis=1
    )

    # Lem
    # df['text_lem'] = df.apply(
    #     lambda row: nlp_utils.word_net_lemmatizer(row['text']),
    #     axis=1
    # )


    print('\n\n 3-gram')
    df['3gram'] = nlp_utils.counter_gram(df['text_stem'],3)
  
    print('\n\n 1-gram')
    df['1gram'] = nlp_utils.counter_gram(df['text_stem'],1)
    print('\n\n 2-gram')
    df['2gram'] = nlp_utils.counter_gram(df['text_stem'],2)

    print(df.head())
    df = df_utils.drop_col_with_name(df, "text")
    return df

# %%
def explore_and_plot_df(df):
    df_utils.print_dataframe_essential_info(df, np)
    pass

# %%
def feature_extraction_binary_transform(df):
    df = df_utils.drop_rows_with_null(df)

    vectorization = CountVectorizer(binary=True)

    xv_train = vectorization.fit_transform(df['text_stem'])
    y = df['c']

    return xv_train, y

# %%
def feature_extraction_CountVectorize(df):
    df = df_utils.drop_rows_with_null(df)

    vectorization = CountVectorizer()

    xv_train = vectorization.fit_transform(df['text_stem'])
    y = df['c']

    return xv_train, y

# %%
def feature_extraction_TfidfVectorize(df):
    df = df_utils.drop_rows_with_null(df)

    vectorization = TfidfVectorizer()

    xv_train = vectorization.fit_transform(df['text_stem'])
    y = df['c']

    return xv_train, y

# %%
def train_model(x_train, y_train):
    """
    Using Two Models MultinomialNB return as NVB & SVC return as SCV
    """
    NVB = MultinomialNB()
    NVB.fit(x_train, y_train)
    SCV = SVC(gamma='auto')
    SCV.fit(x_train, y_train)
    RFC = RandomForestClassifier(random_state=0)
    RFC.fit(x_train, y_train)

    return NVB, SCV, RFC

# %%
def save_model(model, path):
    pickle.dump(model, open(path, 'wb'))

# %%
def make_predictions(model_path, x_test):
    loaded_model = pickle.load(open(model_path, 'rb'))
    predictions = loaded_model.predict(x_test)
    return predictions

# %%
def evaluation(model_path, x_test, y_test):
    loaded_model = pickle.load(open(model_path, 'rb'))
    result = loaded_model.score(x_test, y_test)
    y_hat = loaded_model.predict(x_test)
    print(metrics.confusion_matrix(y_test, y_hat))
    return result

# %%
def main_binary_encoding():
    X, y = feature_extraction_binary_transform(df)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    NVB, SVC, RFC = train_model(X_train, y_train)
    save_model(NVB, 'NVB.sav')
    save_model(SVC, 'SVC.sav')
    save_model(RFC, 'RFC.sav')
    #make_predictions('NVB.sav',x_test)
    #NVB
    print('Naive Bayes Accuracy\n\n')
    print(evaluation('NVB.sav', X_test, y_test))
    print('SVC Accuracy\n\n')
    print(evaluation('SVC.sav', X_test, y_test))
    print('RFC Accuracy\n\n')
    print(evaluation('RFC.sav', X_test, y_test))

# %%
def main_CountVectorize():
    X, y = feature_extraction_CountVectorize(df)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    NVB, SVC, RFC = train_model(X_train, y_train)
    save_model(NVB, 'NVB.sav')
    save_model(SVC, 'SVC.sav')
    save_model(RFC, 'RFC.sav')
    #make_predictions('NVB.sav',x_test)
    #NVB
    print('Naive Bayes Accuracy\n\n')
    print(evaluation('NVB.sav', X_test, y_test))
    print('SVC Accuracy\n\n')
    print(evaluation('SVC.sav', X_test, y_test))
    print('RFC Accuracy\n\n')
    print(evaluation('RFC.sav', X_test, y_test))

# %%
def main_TfidfVectorize():
    X, y = feature_extraction_TfidfVectorize(df)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    NVB, SVC, RFC = train_model(X_train, y_train)
    save_model(NVB, 'NVB.sav')
    save_model(SVC, 'SVC.sav')
    save_model(RFC, 'RFC.sav')
    #make_predictions('NVB.sav',x_test)
    #NVB
    print('Naive Bayes Accuracy\n\n')
    print(evaluation('NVB.sav', X_test, y_test))
    print('SVC Accuracy\n\n')
    print(evaluation('SVC.sav', X_test, y_test))
    print('RFC Accuracy\n\n')
    print(evaluation('RFC.sav', X_test, y_test))

# %%
if __name__ == "__main__":
    nlp_utils.download_book()
    df = prepare_data_frame()
    #vocab = sorted(set(word for sentence in df['text_stem'] for word in sentence.split()))
    print('binary_encoding\n\n')
    main_binary_encoding()
    # print('CountVectorize\n\n')
    # main_CountVectorize()
    # print('TfidfVectorize\n\n')
    # main_TfidfVectorize()
# Out:
# [nltk_data] Error loading book: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# Data frame shape: (3, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    3 non-null      object
#  1   text     3 non-null      object
#  2   subject  3 non-null      object
#  3   date     3 non-null      object
#  4   c        3 non-null      int64
# dtypes: int64(1), object(4)
# memory usage: 248.0+ bytes
# Data frame info: None
#
# ---Data Correlation ---
#      c
# c  1.0
#
# ---Data frame null count ---
# title      0
# text       0
# subject    0
# date       0
# c          0
# dtype: int64
#
# Total values : 15
# Total missing values : 0
# Remaining : 15
#
# Remaining percentage : 100.0%
# Missing percentage : 0.0%
# ---
#
#
#  3-gram
#
#  Result_Create Gram
#
# ['berlin reuter ten', 'reuter ten peopl', 'ten peopl went', 'peopl went trial', 'went trial germani', 'trial germani friday', 'germani friday alleg', 'friday alleg failur', 'alleg failur plan', 'failur plan love', 'plan love parad', 'love parad music', 'parad music festiv', 'music festiv 2010', 'festiv 2010 21', '2010 21 peopl', '21 peopl kill', 'peopl kill 650', 'kill 650 injur', '650 injur stamped', 'injur stamped prosecutor', 'stamped prosecutor charg', 'prosecutor charg defend', 'charg defend four', 'defend four employe', 'four employe compani', 'employe compani plan', 'compani plan event', 'plan event industri', 'event industri citi', 'industri citi duisburg', 'citi duisburg six', 'duisburg six local', 'six local author', 'local author neglig', 'author neglig manslaught', 'neglig manslaught bodili', 'manslaught bodili harm', 'bodili harm defend', 'harm defend deni', 'defend deni wrongdo', 'deni wrongdo disast', 'wrongdo disast eight', 'disast eight foreign', 'eight foreign spain', 'foreign spain bosnia', 'spain bosnia netherland', 'bosnia netherland australia', 'netherland australia itali', 'australia itali china', 'itali china among', 'china among kill', 'among kill juli', 'kill juli 24', 'juli 24 2010', '24 2010 panic', '2010 panic broke', 'panic broke pack', 'broke pack underpass', 'pack underpass entranc', 'underpass entranc rout', 'entranc rout venu', 'rout venu techno', 'venu techno music', 'techno music festiv', 'music festiv trial', 'festiv trial move', 'trial move congress', 'move congress center', 'congress center nearbi', 'center nearbi citi', 'nearbi citi duesseldorf', 'citi duesseldorf court', 'duesseldorf court room', 'court room duisburg', 'room duisburg small', 'duisburg small expect', 'small expect one', 'expect one biggest', 'one biggest trial', 'biggest trial postwar', 'trial postwar germani', 'postwar germani dozen', 'germani dozen lawyer', 'dozen lawyer plaintiff', 'lawyer plaintiff trial', 'plaintiff trial expect', 'trial expect take', 'expect take least', 'take least end', 'least end next', 'end next year', 'next year tick', 'year tick clock', 'tick clock proceed', 'clock proceed statut', 'proceed statut limit', 'statut limit run', 'limit run juli', 'run juli 2020', 'juli 2020 madrid', '2020 madrid reuter', 'madrid reuter half', 'reuter half spanish', 'half spanish voter', 'spanish voter favor', 'voter favor earli', 'favor earli nation', 'earli nation elect', 'nation elect survey', 'elect survey show', 'survey show monday', 'show monday support', 'monday support wane', 'support wane minor', 'wane minor govern', 'minor govern embroil', 'govern embroil countri', 'embroil countri worst', 'countri worst polit', 'worst polit crisi', 'polit crisi decad', 'crisi decad prime', 'decad prime minist', 'prime minist mariano', 'minist mariano rajoy', 'mariano rajoy impos', 'rajoy impos direct', 'impos direct rule', 'direct rule region', 'rule region catalonia', 'region catalonia held', 'catalonia held independ', 'held independ referendum', 'independ referendum oct', 'referendum oct 1', 'oct 1 spanish', '1 spanish court', 'spanish court declar', 'court declar illeg', 'declar illeg term', 'illeg term minor', 'term minor govern', 'minor govern led', 'govern led centerright', 'led centerright peopl', 'centerright peopl parti', 'peopl parti pp', 'parti pp expir', 'pp expir 2020', 'expir 2020 55', '2020 55 percent', '55 percent respond', 'percent respond monday', 'respond monday survey', 'monday survey said', 'survey said want', 'said want ballot', 'want ballot then', 'ballot then figur', 'then figur equival', 'figur equival survey', 'equival survey octob', 'survey octob 49', 'octob 49 percent', '49 percent poll', 'percent poll taken', 'poll taken pollster', 'taken pollster metroscopia', 'pollster metroscopia newspap', 'metroscopia newspap el', 'newspap el pai', 'el pai newspap', 'pai newspap nov', 'newspap nov 6', 'nov 6 8', '6 8 former', '8 former catalan', 'former catalan presid', 'catalan presid carl', 'presid car ...
#
#  Result_Create Gram
#
# ['berlin reuter', 'reuter ten', 'ten peopl', 'peopl went', 'went trial', 'trial germani', 'germani friday', 'friday alleg', 'alleg failur', 'failur plan', 'plan love', 'love parad', 'parad music', 'music festiv', 'festiv 2010', '2010 21', '21 peopl', 'peopl kill', 'kill 650', '650 injur', 'injur stamped', 'stamped prosecutor', 'prosecutor charg', 'charg defend', 'defend four', 'four employe', 'employe compani', 'compani plan', 'plan event', 'event industri', 'industri citi', 'citi duisburg', 'duisburg six', 'six local', 'local author', 'author neglig', 'neglig manslaught', 'manslaught bodili', 'bodili harm', 'harm defend', 'defend deni', 'deni wrongdo', 'wrongdo disast', 'disast eight', 'eight foreign', 'foreign spain', 'spain bosnia', 'bosnia netherland', 'netherland australia', 'australia itali', 'itali china', 'china among', 'among kill', 'kill juli', 'juli 24', '24 2010', '2010 panic', 'panic broke', 'broke pack', 'pack underpass', 'underpass entranc', 'entranc rout', 'rout venu', 'venu techno', 'techno music', 'music festiv', 'festiv trial', 'trial move', 'move congress', 'congress center', 'center nearbi', 'nearbi citi', 'citi duesseldorf', 'duesseldorf court', 'court room', 'room duisburg', 'duisburg small', 'small expect', 'expect one', 'one biggest', 'biggest trial', 'trial postwar', 'postwar germani', 'germani dozen', 'dozen lawyer', 'lawyer plaintiff', 'plaintiff trial', 'trial expect', 'expect take', 'take least', 'least end', 'end next', 'next year', 'year tick', 'tick clock', 'clock proceed', 'proceed statut', 'statut limit', 'limit run', 'run juli', 'juli 2020', '2020 madrid', 'madrid reuter', 'reuter half', 'half spanish', 'spanish voter', 'voter favor', 'favor earli', 'earli nation', 'nation elect', 'elect survey', 'survey show', 'show monday', 'monday support', 'support wane', 'wane minor', 'minor govern', 'govern embroil', 'embroil countri', 'countri worst', 'worst polit', 'polit crisi', 'crisi decad', 'decad prime', 'prime minist', 'minist mariano', 'mariano rajoy', 'rajoy impos', 'impos direct', 'direct rule', 'rule region', 'region catalonia', 'catalonia held', 'held independ', 'independ referendum', 'referendum oct', 'oct 1', '1 spanish', 'spanish court', 'court declar', 'declar illeg', 'illeg term', 'term minor', 'minor govern', 'govern led', 'led centerright', 'centerright peopl', 'peopl parti', 'parti pp', 'pp expir', 'expir 2020', '2020 55', '55 percent', 'percent respond', 'respond monday', 'monday survey', 'survey said', 'said want', 'want ballot', 'ballot then', 'then figur', 'figur equival', 'equival survey', 'survey octob', 'octob 49', '49 percent', 'percent poll', 'poll taken', 'taken pollster', 'pollster metroscopia', 'metroscopia newspap', 'newspap el', 'el pai', 'pai newspap', 'newspap nov', 'nov 6', '6 8', '8 former', 'former catalan', 'catalan presid', 'presid carl', 'carl puigdemont', 'puigdemont whose', 'whose govern', 'govern sack', 'sack rajoy', 'rajoy pursu', 'pursu campaign', 'campaign region', 'region independ', 'independ selfimpos', 'selfimpos exil', 'exil belgium', 'belgium author', 'author madrid', 'madrid call', 'call elect', 'elect catalonia', 'catalonia dec', 'dec 21', '21 rajoy', 'rajoy given', 'given second', 'second term', 'term octob', 'octob 2016', '2016 pp', 'pp vote', 'vote fail', 'fail take', 'take parliament', 'parliament major', 'major pp', 'pp weak', 'weak parliament', 'parliament meant', 'meant govern', 'govern struggl', 'struggl pass', 'pass legisl', 'legisl includ', 'includ 2018', '2018 budget', 'budget support', 'support pp', 'pp elect', 'elect held', 'held today', 'today slip', 'slip 261', '261 percent', 'percent novemb', 'novemb 269', '269 percent', 'percent juli', 'juli back', 'back ciudadano', 'ciudadano citizen', 'citizen prospanish', 'prospanish uniti', 'uniti parti', 'parti origin', 'origin catalonia', 'catalonia jump', 'jump 227', '227 percent', 'percent 185', '185 percent', 'percent put', 'put equal', 'equal second', 'second socialist', 'socialist poll' ...
# Counter({'berlin reuter ten': 1, 'reuter ten peopl': 1, 'ten peopl went': 1, 'peopl went trial': 1, 'went trial germani': 1, 'trial germani friday': 1, 'germani friday alleg': 1, 'friday alleg failur': 1, 'alleg failur plan': 1, 'failur plan love': 1, 'plan love parad': 1, 'love parad music': 1, 'parad music festiv': 1, 'music festiv 2010': 1, 'festiv 2010 21': 1, '2010 21 peopl': 1, '21 peopl kill': 1, 'peopl kill 650': 1, 'kill 650 injur': 1, '650 injur stamped': 1, 'injur stamped prosecutor': 1, 'stamped prosecutor charg': 1, 'prosecutor charg defend': 1, 'charg defend four': 1, 'defend four employe': 1, 'four employe compani': 1, 'employe compani plan': 1, 'compani plan event': 1, 'plan event industri': 1, 'event industri citi': 1, 'industri citi duisburg': 1, 'citi duisburg six': 1, 'duisburg six local': 1, 'six local author': 1, 'local author neglig': 1, 'author neglig manslaught': 1, 'neglig manslaught bodili': 1, 'manslaught bodili harm': 1, 'bodili harm defend': 1, 'harm defend deni': 1, 'defend deni wrongdo': 1, 'deni wrongdo disast': 1, 'wrongdo disast eight': 1, 'disast eight foreign': 1, 'eight foreign spain': 1, 'foreign spain bosnia': 1, 'spain bosnia netherland': 1, 'bosnia netherland australia': 1, 'netherland australia itali': 1, 'australia itali china': 1, 'itali china among': 1, 'china among kill': 1, 'among kill juli': 1, 'kill juli 24': 1, 'juli 24 2010': 1, '24 2010 panic': 1, '2010 panic broke': 1, 'panic broke pack': 1, 'broke pack underpass': 1, 'pack underpass entranc': 1, 'underpass entranc rout': 1, 'entranc rout venu': 1, 'rout venu techno': 1, 'venu techno music': 1, 'techno music festiv': 1, 'music festiv trial': 1, 'festiv trial move': 1, 'trial move congress': 1, 'move congress center': 1, 'congress center nearbi': 1, 'center nearbi citi': 1, 'nearbi citi duesseldorf': 1, 'citi duesseldorf court': 1, 'duesseldorf court room': 1, 'court room duisburg': 1, 'room duisburg small': 1, 'duisburg small expect': 1, 'small expect one': 1, 'expect one biggest': 1, 'one biggest trial': 1, 'biggest trial postwar': 1, 'trial postwar germani': 1, 'postwar germani dozen': 1, 'germani dozen lawyer': 1, 'dozen lawyer plaintiff': 1, 'lawyer plaintiff trial': 1, 'plaintiff trial expect': 1, 'trial expect take': 1, 'expect take least': 1, 'take least end': 1, 'least end next': 1, 'end next year': 1, 'next year tick': 1, 'year tick clock': 1, 'tick clock proceed': 1, 'clock proceed statut': 1, 'proceed statut limit': 1, 'statut limit run': 1, 'limit run juli': 1, 'run juli 2020': 1, 'juli 2020 madrid': 1, '2020 madrid reuter': 1, 'madrid reuter half': 1, 'reuter half spanish': 1, 'half spanish voter': 1, 'spanish voter favor': 1, 'voter favor earli': 1, 'favor earli nation': 1, 'earli nation elect': 1, 'nation elect survey': 1, 'elect survey show': 1, 'survey show monday': 1, 'show monday support': 1, 'monday support wane': 1, 'support wane minor': 1, 'wane minor govern': 1, 'minor govern embroil': 1, 'govern embroil countri': 1, 'embroil countri worst': 1, 'countri worst polit': 1, 'worst polit crisi': 1, 'polit crisi decad': 1, 'crisi decad prime': 1, 'decad prime minist': 1, 'prime minist mariano': 1, 'minist mariano rajoy': 1, 'mariano rajoy impos': 1, 'rajoy impos direct': 1, 'impos direct rule': 1, 'direct rule region': 1, 'rule region catalonia': 1, 'region catalonia held': 1, 'catalonia held independ': 1, 'held independ referendum': 1, 'independ referendum oct': 1, 'referendum oct 1': 1, 'oct 1 spanish': 1, '1 spanish court': 1, 'spanish court declar': 1, 'court declar illeg': 1, 'declar illeg term': 1, 'illeg term minor': 1, 'term minor govern': 1, 'minor govern led': 1, 'govern led centerright': 1, 'led centerright peopl': 1, 'centerright peopl parti': 1, 'peopl parti pp': 1, 'parti pp expir': 1, 'pp expir 2020': 1, 'expir 2020 55': 1, '2020 55 percent': 1, '55 percent respond': 1, 'percent respond monday': 1, 'respond monday survey': 1, 'monday survey said': 1, 'survey said want': 1, 'said want ballot': ...
# Counter({'music festiv': 2, 'minor govern': 2, 'berlin reuter': 1, 'reuter ten': 1, 'ten peopl': 1, 'peopl went': 1, 'went trial': 1, 'trial germani': 1, 'germani friday': 1, 'friday alleg': 1, 'alleg failur': 1, 'failur plan': 1, 'plan love': 1, 'love parad': 1, 'parad music': 1, 'festiv 2010': 1, '2010 21': 1, '21 peopl': 1, 'peopl kill': 1, 'kill 650': 1, '650 injur': 1, 'injur stamped': 1, 'stamped prosecutor': 1, 'prosecutor charg': 1, 'charg defend': 1, 'defend four': 1, 'four employe': 1, 'employe compani': 1, 'compani plan': 1, 'plan event': 1, 'event industri': 1, 'industri citi': 1, 'citi duisburg': 1, 'duisburg six': 1, 'six local': 1, 'local author': 1, 'author neglig': 1, 'neglig manslaught': 1, 'manslaught bodili': 1, 'bodili harm': 1, 'harm defend': 1, 'defend deni': 1, 'deni wrongdo': 1, 'wrongdo disast': 1, 'disast eight': 1, 'eight foreign': 1, 'foreign spain': 1, 'spain bosnia': 1, 'bosnia netherland': 1, 'netherland australia': 1, 'australia itali': 1, 'itali china': 1, 'china among': 1, 'among kill': 1, 'kill juli': 1, 'juli 24': 1, '24 2010': 1, '2010 panic': 1, 'panic broke': 1, 'broke pack': 1, 'pack underpass': 1, 'underpass entranc': 1, 'entranc rout': 1, 'rout venu': 1, 'venu techno': 1, 'techno music': 1, 'festiv trial': 1, 'trial move': 1, 'move congress': 1, 'congress center': 1, 'center nearbi': 1, 'nearbi citi': 1, 'citi duesseldorf': 1, 'duesseldorf court': 1, 'court room': 1, 'room duisburg': 1, 'duisburg small': 1, 'small expect': 1, 'expect one': 1, 'one biggest': 1, 'biggest trial': 1, 'trial postwar': 1, 'postwar germani': 1, 'germani dozen': 1, 'dozen lawyer': 1, 'lawyer plaintiff': 1, 'plaintiff trial': 1, 'trial expect': 1, 'expect take': 1, 'take least': 1, 'least end': 1, 'end next': 1, 'next year': 1, 'year tick': 1, 'tick clock': 1, 'clock proceed': 1, 'proceed statut': 1, 'statut limit': 1, 'limit run': 1, 'run juli': 1, 'juli 2020': 1, '2020 madrid': 1, 'madrid reuter': 1, 'reuter half': 1, 'half spanish': 1, 'spanish voter': 1, 'voter favor': 1, 'favor earli': 1, 'earli nation': 1, 'nation elect': 1, 'elect survey': 1, 'survey show': 1, 'show monday': 1, 'monday support': 1, 'support wane': 1, 'wane minor': 1, 'govern embroil': 1, 'embroil countri': 1, 'countri worst': 1, 'worst polit': 1, 'polit crisi': 1, 'crisi decad': 1, 'decad prime': 1, 'prime minist': 1, 'minist mariano': 1, 'mariano rajoy': 1, 'rajoy impos': 1, 'impos direct': 1, 'direct rule': 1, 'rule region': 1, 'region catalonia': 1, 'catalonia held': 1, 'held independ': 1, 'independ referendum': 1, 'referendum oct': 1, 'oct 1': 1, '1 spanish': 1, 'spanish court': 1, 'court declar': 1, 'declar illeg': 1, 'illeg term': 1, 'term minor': 1, 'govern led': 1, 'led centerright': 1, 'centerright peopl': 1, 'peopl parti': 1, 'parti pp': 1, 'pp expir': 1, 'expir 2020': 1, '2020 55': 1, '55 percent': 1, 'percent respond': 1, 'respond monday': 1, 'monday survey': 1, 'survey said': 1, 'said want': 1, 'want ballot': 1, 'ballot then': 1, 'then figur': 1, 'figur equival': 1, 'equival survey': 1, 'survey octob': 1, 'octob 49': 1, '49 percent': 1, 'percent poll': 1, 'poll taken': 1, 'taken pollster': 1, 'pollster metroscopia': 1, 'metroscopia newspap': 1, 'newspap el': 1, 'el pai': 1, 'pai newspap': 1, 'newspap nov': 1, 'nov 6': 1, '6 8': 1, '8 former': 1, 'former catalan': 1, 'catalan presid': 1, 'presid carl': 1, 'carl puigdemont': 1, 'puigdemont whose': 1, 'whose govern': 1, 'govern sack': 1, 'sack rajoy': 1, 'rajoy pursu': 1, 'pursu campaign': 1, 'campaign region': 1, 'region independ': 1, 'independ selfimpos': 1, 'selfimpos exil': 1, 'exil belgium': 1, 'belgium author': 1, 'author madrid': 1, 'madrid call': 1, 'call elect': 1, 'elect catalonia': 1, 'catalonia dec': 1, 'dec 21': 1, '21 rajoy': 1, 'rajoy given': 1, 'given second': 1, 'second term': 1, 'term octob': 1, 'octob 2016': 1, '2016 pp': 1, 'pp vote': 1, 'vote fail': 1, 'fail take': 1, 'take parliament': 1, 'parliament major': 1, 'major pp': 1, 'pp weak': 1, 'weak parliamen ...
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print0.5
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print0.5
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print0.5
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print0.5
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
# Print1.0
#
#
#  1-gram
#
#  Result_Create Gram
#
# ['berlin', 'reuter', 'ten', 'peopl', 'went', 'trial', 'germani', 'friday', 'alleg', 'failur', 'plan', 'love', 'parad', 'music', 'festiv', '2010', '21', 'peopl', 'kill', '650', 'injur', 'stamped', 'prosecutor', 'charg', 'defend', 'four', 'employe', 'compani', 'plan', 'event', 'industri', 'citi', 'duisburg', 'six', 'local', 'author', 'neglig', 'manslaught', 'bodili', 'harm', 'defend', 'deni', 'wrongdo', 'disast', 'eight', 'foreign', 'spain', 'bosnia', 'netherland', 'australia', 'itali', 'china', 'among', 'kill', 'juli', '24', '2010', 'panic', 'broke', 'pack', 'underpass', 'entranc', 'rout', 'venu', 'techno', 'music', 'festiv', 'trial', 'move', 'congress', 'center', 'nearbi', 'citi', 'duesseldorf', 'court', 'room', 'duisburg', 'small', 'expect', 'one', 'biggest', 'trial', 'postwar', 'germani', 'dozen', 'lawyer', 'plaintiff', 'trial', 'expect', 'take', 'least', 'end', 'next', 'year', 'tick', 'clock', 'proceed', 'statut', 'limit', 'run', 'juli', '2020', 'madrid', 'reuter', 'half', 'spanish', 'voter', 'favor', 'earli', 'nation', 'elect', 'survey', 'show', 'monday', 'support', 'wane', 'minor', 'govern', 'embroil', 'countri', 'worst', 'polit', 'crisi', 'decad', 'prime', 'minist', 'mariano', 'rajoy', 'impos', 'direct', 'rule', 'region', 'catalonia', 'held', 'independ', 'referendum', 'oct', '1', 'spanish', 'court', 'declar', 'illeg', 'term', 'minor', 'govern', 'led', 'centerright', 'peopl', 'parti', 'pp', 'expir', '2020', '55', 'percent', 'respond', 'monday', 'survey', 'said', 'want', 'ballot', 'then', 'figur', 'equival', 'survey', 'octob', '49', 'percent', 'poll', 'taken', 'pollster', 'metroscopia', 'newspap', 'el', 'pai', 'newspap', 'nov', '6', '8', 'former', 'catalan', 'presid', 'carl', 'puigdemont', 'whose', 'govern', 'sack', 'rajoy', 'pursu', 'campaign', 'region', 'independ', 'selfimpos', 'exil', 'belgium', 'author', 'madrid', 'call', 'elect', 'catalonia', 'dec', '21', 'rajoy', 'given', 'second', 'term', 'octob', '2016', 'pp', 'vote', 'fail', 'take', 'parliament', 'major', 'pp', 'weak', 'parliament', 'meant', 'govern', 'struggl', 'pass', 'legisl', 'includ', '2018', 'budget', 'support', 'pp', 'elect', 'held', 'today', 'slip', '261', 'percent', 'novemb', '269', 'percent', 'juli', 'back', 'ciudadano', 'citizen', 'prospanish', 'uniti', 'parti', 'origin', 'catalonia', 'jump', '227', 'percent', '185', 'percent', 'put', 'equal', 'second', 'socialist', 'poll', 'reflect', 'offici', 'survey', 'taken', 'begin', 'octob', 'show', 'support', 'ciudadano', 'risen', 'catalan', 'crisi', 'becom', 'spaniard', 'secondlargest', 'issu', 'concern', 'unemploy', 'leftw', 'podemo', 'support', 'negoti', 'referendum', 'catalan', 'independ', 'saw', 'vote', 'intent', 'drop', '147', 'percent', '187', 'percent', 'previous', 'metroscopia', 'poll', 'show']
#
#  Result_Create Gram
#
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# Counter({'percent': 8, 'trial': 4, 'survey': 4, 'support': 4, 'govern': 4, 'pp': 4, 'peopl': 3, 'juli': 3, 'elect': 3, 'show': 3, 'rajoy': 3, 'catalonia': 3, 'independ': 3, 'octob': 3, 'poll': 3, 'catalan': 3, 'reuter': 2, 'germani': 2, 'plan': 2, 'music': 2, 'festiv': 2, '2010': 2, '21': 2, 'kill': 2, 'defend': 2, 'citi': 2, 'duisburg': 2, 'author': 2, 'court': 2, 'expect': 2, 'take': 2, '2020': 2, 'madrid': 2, 'spanish': 2, 'monday': 2, 'minor': 2, 'crisi': 2, 'region': 2, 'held': 2, 'referendum': 2, 'term': 2, 'parti': 2, 'taken': 2, 'metroscopia': 2, 'newspap': 2, 'second': 2, 'vote': 2, 'parliament': 2, 'ciudadano': 2, 'berlin': 1, 'ten': 1, 'went': 1, 'friday': 1, 'alleg': 1, 'failur': 1, 'love': 1, 'parad': 1, '650': 1, 'injur': 1, 'stamped': 1, 'prosecutor': 1, 'charg': 1, 'four': 1, 'employe': 1, 'compani': 1, 'event': 1, 'industri': 1, 'six': 1, 'local': 1, 'neglig': 1, 'manslaught': 1, 'bodili': 1, 'harm': 1, 'deni': 1, 'wrongdo': 1, 'disast': 1, 'eight': 1, 'foreign': 1, 'spain': 1, 'bosnia': 1, 'netherland': 1, 'australia': 1, 'itali': 1, 'china': 1, 'among': 1, '24': 1, 'panic': 1, 'broke': 1, 'pack': 1, 'underpass': 1, 'entranc': 1, 'rout': 1, 'venu': 1, 'techno': 1, 'move': 1, 'congress': 1, 'center': 1, 'nearbi': 1, 'duesseldorf': 1, 'room': 1, 'small': 1, 'one': 1, 'biggest': 1, 'postwar': 1, 'dozen': 1, 'lawyer': 1, 'plaintiff': 1, 'least': 1, 'end': 1, 'next': 1, 'year': 1, 'tick': 1, 'clock': 1, 'proceed': 1, 'statut': 1, 'limit': 1, 'run': 1, 'half': 1, 'voter': 1, 'favor': 1, 'earli': 1, 'nation': 1, 'wane': 1, 'embroil': 1, 'countri': 1, 'worst': 1, 'polit': 1, 'decad': 1, 'prime': 1, 'minist': 1, 'mariano': 1, 'impos': 1, 'direct': 1, 'rule': 1, 'oct': 1, '1': 1, 'declar': 1, 'illeg': 1, 'led': 1, 'centerright': 1, 'expir': 1, '55': 1, 'respond': 1, 'said': 1, 'want': 1, 'ballot': 1, 'then': 1, 'figur': 1, 'equival': 1, '49': 1, 'pollster': 1, 'el': 1, 'pai': 1, 'nov': 1, '6': 1, '8': 1, 'former': 1, 'presid': 1, 'carl': 1, 'puigdemont': 1, 'whose': 1, 'sack': 1, 'pursu': 1, 'campaign': 1, 'selfimpos': 1, 'exil': 1, 'belgium': 1, 'call': 1, 'dec': 1, 'given': 1, '2016': 1, 'fail': 1, 'major': 1, 'weak': 1, 'meant': 1, 'struggl': 1, 'pass': 1, 'legisl': 1, 'includ': 1, '2018': 1, 'budget': 1, 'today': 1, 'slip': 1, '261': 1, 'novemb': 1, '269': 1, 'back': 1, 'citizen': 1, 'prospanish': 1, 'uniti': 1, 'origin': 1, 'jump': 1, '227': 1, '185': 1, 'put': 1, 'equal': 1, 'socialist': 1, 'reflect': 1, 'offici': 1, 'begin': 1, 'risen': 1, 'becom': 1, 'spaniard': 1, 'secondlargest': 1, 'issu': 1, 'concern': 1, 'unemploy': 1, 'leftw': 1, 'podemo': 1, 'negoti': 1, 'saw': 1, 'intent': 1, 'drop': 1, '147': 1, '187': 1, 'previous': 1})
# Counter({'': 292})
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-02d61b94e006> in <module>
#       1 if __name__ == "__main__":
#       2     nlp_utils.download_book()
# ----> 3     df = prepare_data_frame()
#       4     #vocab = sorted(set(word for sentence in df['text_stem'] for word in sentence.split()))
#       5     print('binary_encoding\n\n')
#
# <ipython-input-3-fbf4e211401e> in prepare_data_frame()
#       5     explore_and_plot_df(df)
#       6     # Enhance
# ----> 7     df = enhance(df)
#       8     # Explore & Plot - 2
#       9     explore_and_plot_df(df)
#
# <ipython-input-4-2dc485d2b541> in enhance(df)
#       3     df = df_utils.drop_rows_with_null(df)
#       4     # Corpus calculations as text
# ----> 5     df = process_df_text(df)
#       6
#       7     return df
#
# <ipython-input-5-cece282d73ee> in process_df_text(df)
#      40
#      41     print('\n\n 1-gram')
# ---> 42     df['1gram'] = nlp_utils.counter_gram(df['text_stem'],1)
#      43     print('\n\n 2-gram')
#      44     df['2gram'] = nlp_utils.counter_gram(df['text_stem'],2)
#
# ~\Desktop\4-CS\First-Term\NLP\utils\nlp_utils.py in counter_gram(text, n)
#      92
#      93 def counter_gram(text, n):
# ---> 94     printGramsCount(text, n)
#      95     # tokens = create_gram(text, n)
#      96     # counter = Counter(tokens)
#
# ~\Desktop\4-CS\First-Term\NLP\utils\nlp_utils.py in printGramsCount(text, n)
#      87     for gram in grams:
#      88         n_1_gram = " ".join(gram.split()[:2])
# ---> 89         prob = nGCount[gram] / n_1GCount[n_1_gram]
#      90         print(f"Print{prob}")
#      91
#
# ZeroDivisionError: division by zero

# %%
print('binary_encoding\n\n')
main_binary_encoding()
